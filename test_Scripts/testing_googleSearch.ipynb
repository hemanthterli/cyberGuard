# %%
print("hiii")
# Out:
# hiii

# %%
from google import genai
from google.genai import types
from dotenv import load_dotenv
import os

# Load env
load_dotenv()
api_key = os.getenv("GEMINI_API_KEY")

if not api_key:
    raise ValueError("Missing GEMINI_API_KEY in .env")

client = genai.Client(api_key=api_key)

response = client.models.generate_content(
    model="gemini-3-flash-preview",
    contents="Latest RBI and banking cyber laws in india in 2026",
    config=types.GenerateContentConfig(
        tools=[
            {"google_search": {}}  # ✅ correct for your SDK
        ]
        # ❌ REMOVE this line:
        # include_server_side_tool_invocations=True
    ),
)

# Print response safely
for part in response.candidates[0].content.parts:
    if hasattr(part, "text") and part.text:
        print(part.text)
# Out:
# As of March 2026, India’s banking and cybersecurity landscape has undergone a significant overhaul. The Reserve Bank of India (RBI) and the Ministry of Electronics and Information Technology (MeitY) have moved from "advisory" frameworks to strict, enforceable laws focusing on **customer liability, AI-driven fraud prevention, and data privacy.**
#
# The following are the most critical updates and laws in effect as of March 2026:
#
# ### 1. The "Responsible Business Conduct" Amendment (Draft 2026)
# In March 2026, the RBI issued the **Third Amendment Directions, 2026**, which significantly updates customer protection for digital transactions. These rules are set to become fully enforceable on **July 1, 2026**, but banks are already transitioning.
# *   **Small-Value Fraud Compensation:** For the first time, a structured compensation mechanism is introduced for small-value digital frauds (up to ₹50,000). Eligible victims can receive **85% of the net loss** (capped at ₹25,000) as a once-in-a-lifetime benefit.
# *   **Zero Liability Rule:** Customers have zero liability if fraud occurs due to bank negligence or a third-party breach (e.g., at a payment gateway or telecom provider), provided the incident is reported within five calendar days.
# *   **Mule Account Detection:** Banks are now mandated to use AI tools like **MuleHunter.AI** (introduced by RBI/IDPIC) to detect and freeze "mule accounts" in real-time to prevent the layering of stolen funds.
#
# ### 2. Digital Banking Authorization (Effective Jan 1, 2026)
# Starting **January 1, 2026**, banks are required to have **explicit authorization** for each digital channel they offer (Internet, Mobile, USSD, and SMS banking).
# *   **Stricter Audit Standards:** Banks can no longer offer these services under "general" banking licenses. They must meet higher cybersecurity maturity levels and undergo specialized digital-asset audits.
# *   **Mandatory Consent:** Banks must obtain documented, granular customer consent before enabling any digital banking service for an account.
#
# ### 3. New Authentication Framework (Effective April 1, 2026)
# The RBI is shifting away from "OTP-only" security to a **Risk-Based Authentication (RBA)** framework, mandatory from **April 1, 2026**.
# *   **Beyond OTP:** Banks must implement alternative authentication methods like **biometrics, device fingerprinting, and behavior analytics** for high-value or high-risk transactions.
# *   **Two-Factor Mandate:** All administrative and customer-facing system access points must now use Multi-Factor Authentication (MFA).
#
# ### 4. Digital Personal Data Protection (DPDP) Act & Rules 2025
# Following the notification of the **DPDP Rules in November 2025**, the banking sector is now under intense data privacy scrutiny.
# *   **Significant Data Fiduciaries (SDFs):** Most large commercial banks are now classified as SDFs, requiring them to appoint a **Data Protection Officer (DPO)** and conduct periodic **Data Protection Impact Assessments (DPIAs)**.
# *   **Right to Erasure vs. RBI Retention:** While the DPDP Act grants the "Right to Erasure," it is now legally clarified that **RBI’s 10-year data retention mandate** (for AML/KYC purposes) overrides individual deletion requests.
# *   **Hefty Penalties:** Non-compliance or failure to protect customer data can lead to fines up to **₹250 crore** per incident.
#
# ### 5. Master Direction on IT Governance (2024-2026 Implementation)
# The **Master Direction on IT Governance, Risk, Controls, and Assurance** (originally effective April 2024) has reached full maturity in 2026.
# *   **Board-Level Accountability:** The Board of Directors is now legally responsible for the bank's "Cyber Resilience." A dedicated **IT Strategy Committee** must meet at least quarterly.
# *   **Ring-Fencing Core Banking:** By **March 31, 2026**, all banks were required to submit detailed plans to "ring-fence" their core banking operations from riskier non-banking business entities (Fintech subsidiaries) to prevent contagion in case of a cyberattack.
#
# ### 6. Integrated Physical-Cyber Security
# RBI guidelines in 2026 now emphasize the **integration of physical and cyber security.**
# *   **24/7 Active Monitoring:** CCTV recording alone is no longer sufficient. Banks must have centralized monitoring stations where physical security alerts (like ATM tampering) are integrated with cyber-SOC (Security Operations Center) alerts.
# *   **Incident Reporting:** All "critical" cyber or physical security breaches must be reported to the RBI within **2 to 6 hours** of detection.
#
# ### Summary Table for 2026 Compliance
# | Regulation | Effective Date | Key Impact |
# | :--- | :--- | :--- |
# | **Digital Banking Rules** | Jan 1, 2026 | Explicit channel-wise authorization & audit. |
# | **DPDP Rules** | Nov 14, 2025 | Rights-based data handling & ₹250cr fines. |
# | **Ring-Fencing** | March 2026 | Core banking isolation from risky subsidiaries. |
# | **RBA Framework** | April 1, 2026 | Move from OTPs to Biometrics/Behavioral auth. |
# | **Fraud Amendment** | July 1, 2026 | Up to ₹25,000 compensation for small frauds. |

# %%
import google.genai.types as types
dir(types)
# Out:
# ['ABC',
#  'ActivityEnd',
#  'ActivityEndDict',
#  'ActivityEndOrDict',
#  'ActivityHandling',
#  'ActivityStart',
#  'ActivityStartDict',
#  'ActivityStartOrDict',
#  'AdapterSize',
#  'AggregationMetric',
#  'AggregationOutput',
#  'AggregationOutputDict',
#  'AggregationOutputOrDict',
#  'AggregationResult',
#  'AggregationResultDict',
#  'AggregationResultOrDict',
#  'Any',
#  'ApiAuth',
#  'ApiAuthApiKeyConfig',
#  'ApiAuthApiKeyConfigDict',
#  'ApiAuthApiKeyConfigOrDict',
#  'ApiAuthDict',
#  'ApiAuthOrDict',
#  'ApiKeyConfig',
#  'ApiKeyConfigDict',
#  'ApiKeyConfigOrDict',
#  'ApiSpec',
#  'AudioChunk',
#  'AudioChunkDict',
#  'AudioChunkOrDict',
#  'AudioTranscriptionConfig',
#  'AudioTranscriptionConfigDict',
#  'AudioTranscriptionConfigOrDict',
#  'AuthConfig',
#  'AuthConfigDict',
#  'AuthConfigGoogleServiceAccountConfig',
#  'AuthConfigGoogleServiceAccountConfigDict',
#  'AuthConfigGoogleServiceAccountConfigOrDict',
#  'AuthConfigHttpBasicAuthConfig',
#  'AuthConfigHttpBasicAuthConfigDict',
#  'AuthConfigHttpBasicAuthConfigOrDict',
#  'AuthConfigOauthConfig',
#  'AuthConfigOauthConfigDict',
#  'AuthConfigOauthConfigOrDict',
#  'AuthConfigOidcConfig',
#  'AuthConfigOidcConfigDict',
#  'AuthConfigOidcConfigOrDict',
#  'AuthConfigOrDict',
#  'AuthToken',
#  'AuthTokenDict',
#  'AuthTokenOrDict',
#  'AuthType',
#  'AutomaticActivityDetection',
#  'AutomaticActivityDetectionDict',
#  'AutomaticActivityDetectionOrDict',
#  'AutomaticFunctionCallingConfig',
#  'AutomaticFunctionCallingConfigDict',
#  'AutomaticFunctionCallingConfigOrDict',
#  'AutoraterConfig',
#  'AutoraterConfigDict',
#  'AutoraterConfigOrDict',
#  'BatchJob',
#  'BatchJobDestination',
#  'BatchJobDestinationDict',
#  'BatchJobDestinationOrDict',
#  'BatchJobDestinationUnion',
#  'BatchJobDestinationUnionDict',
#  'BatchJobDict',
#  'BatchJobOrDict',
#  'BatchJobSource',
#  'BatchJobSourceDict',
#  'BatchJobSourceOrDict',
#  'BatchJobSourceUnion',
#  'BatchJobSourceUnionDict',
#  'Behavior',
#  'BigQuerySource',
#  'BigQuerySourceDict',
#  'BigQuerySourceOrDict',
#  'BleuMetricValue',
#  'BleuMetricValueDict',
#  'BleuMetricValueOrDict',
#  'BleuSpec',
#  'BleuSpecDict',
#  'BleuSpecOrDict',
#  'Blob',
#  'BlobDict',
#  'BlobImageUnion',
#  'BlobImageUnionDict',
#  'BlobOrDict',
#  'BlockedReason',
#  'CachedContent',
#  'CachedContentDict',
#  'CachedContentOrDict',
#  'CachedContentUsageMetadata',
#  'CachedContentUsageMetadataDict',
#  'CachedContentUsageMetadataOrDict',
#  'Callable',
#  'CancelBatchJobConfig',
#  'CancelBatchJobConfigDict',
#  'CancelBatchJobConfigOrDict',
#  'CancelTuningJobConfig',
#  'CancelTuningJobConfigDict',
#  'CancelTuningJobConfigOrDict',
#  'CancelTuningJobResponse',
#  'CancelTuningJobResponseDict',
#  'CancelTuningJobResponseOrDict',
#  'Candidate',
#  'CandidateDict',
#  'CandidateOrDict',
#  'Checkpoint',
#  'CheckpointDict',
#  'CheckpointOrDict',
#  'ChunkingConfig',
#  'ChunkingConfigDict',
#  'ChunkingConfigOrDict',
#  'Citation',
#  'CitationDict',
#  'CitationMetadata',
#  'CitationMetadataDict',
#  'CitationMetadataOrDict',
#  'CitationOrDict',
#  'ClientSession',
#  'CodeExecutionResult',
#  'CodeExecutionResultDict',
#  'CodeExecutionResultOrDict',
#  'CompletionStats',
#  'CompletionStatsDict',
#  'CompletionStatsOrDict',
#  'ComputationBasedMetricSpec',
#  'ComputationBasedMetricSpecDict',
#  'ComputationBasedMetricSpecOrDict',
#  'ComputationBasedMetricType',
#  'ComputeTokensConfig',
#  'ComputeTokensConfigDict',
#  'ComputeTokensConfigOrDict',
#  'ComputeTokensResponse',
#  'ComputeTokensResponseDict',
#  'ComputeTokensResponseOrDict',
#  'ComputeTokensResult',
#  'ComputeTokensResultDict',
#  'ComputeTokensResultOrDict',
#  'ComputerUse',
#  'ComputerUseDict',
#  'ComputerUseOrDict',
#  'ConfigDict',
#  'Content',
#  'ContentDict',
#  'ContentEmbedding',
#  'ContentEmbeddingDict',
#  'ContentEmbeddingOrDict',
#  'ContentEmbeddingStatistics',
#  'ContentEmbeddingStatisticsDict',
#  'ContentEmbeddingStatisticsOrDict',
#  'ContentListUnion',
#  'ContentListUnionDict',
#  'ContentOrDict',
#  'ContentReferenceImage',
#  'ContentReferenceImageDict',
#  'ContentReferenceImageOrDict',
#  'ContentUnion',
#  'ContentUnionDict',
#  'ContextWindowCompressionConfig',
#  'ContextWindowCompressionConfigDict',
#  'ContextWindowCompressionConfigOrDict',
#  'ControlReferenceConfig',
#  'ControlReferenceConfigDict',
#  'ControlReferenceConfigOrDict',
#  'ControlReferenceImage',
#  'ControlReferenceImageDict',
#  'ControlReferenceImageOrDict',
#  'ControlReferenceType',
#  'CountTokensConfig',
#  'CountTokensConfigDict',
#  'CountTokensConfigOrDict',
#  'CountTokensResponse',
#  'CountTokensResponseDict',
#  'CountTokensResponseOrDict',
#  'CountTokensResult',
#  'CountTokensResultDict',
#  'CountTokensResultOrDict',
#  'CreateAuthTokenConfig',
#  'CreateAuthTokenConfigDict',
#  'CreateAuthTokenConfigOrDict',
#  'CreateAuthTokenParameters',
#  'CreateAuthTokenParametersDict',
#  'CreateAuthTokenParametersOrDict',
#  'CreateBatchJobConfig',
#  'CreateBatchJobConfigDict',
#  'CreateBatchJobConfigOrDict',
#  'CreateCachedContentConfig',
#  'CreateCachedContentConfigDict',
#  'CreateCachedContentConfigOrDict',
#  'CreateEmbeddingsBatchJobConfig',
#  'CreateEmbeddingsBatchJobConfigDict',
#  'CreateEmbeddingsBatchJobConfigOrDict',
#  'CreateFileConfig',
#  'CreateFileConfigDict',
#  'CreateFileConfigOrDict',
#  'CreateFileResponse',
#  'CreateFileResponseDict',
#  'CreateFileResponseOrDict',
#  'CreateFileSearchStoreConfig',
#  'CreateFileSearchStoreConfigDict',
#  'CreateFileSearchStoreConfigOrDict',
#  'CreateTuningJobConfig',
#  'CreateTuningJobConfigDict',
#  'CreateTuningJobConfigOrDict',
#  'CreateTuningJobParameters',
#  'CreateTuningJobParametersDict',
#  'CreateTuningJobParametersOrDict',
#  'CustomCodeExecutionResult',
#  'CustomCodeExecutionResultDict',
#  'CustomCodeExecutionResultOrDict',
#  'CustomCodeExecutionSpec',
#  'CustomCodeExecutionSpecDict',
#  'CustomCodeExecutionSpecOrDict',
#  'CustomMetadata',
#  'CustomMetadataDict',
#  'CustomMetadataOrDict',
#  'CustomOutput',
#  'CustomOutputDict',
#  'CustomOutputFormatConfig',
#  'CustomOutputFormatConfigDict',
#  'CustomOutputFormatConfigOrDict',
#  'CustomOutputOrDict',
#  'DatasetDistribution',
#  'DatasetDistributionDict',
#  'DatasetDistributionDistributionBucket',
#  'DatasetDistributionDistributionBucketDict',
#  'DatasetDistributionDistributionBucketOrDict',
#  'DatasetDistributionOrDict',
#  'DatasetStats',
#  'DatasetStatsDict',
#  'DatasetStatsOrDict',
#  'DeleteBatchJobConfig',
#  'DeleteBatchJobConfigDict',
#  'DeleteBatchJobConfigOrDict',
#  'DeleteCachedContentConfig',
#  'DeleteCachedContentConfigDict',
#  'DeleteCachedContentConfigOrDict',
#  'DeleteCachedContentResponse',
#  'DeleteCachedContentResponseDict',
#  'DeleteCachedContentResponseOrDict',
#  'DeleteDocumentConfig',
#  'DeleteDocumentConfigDict',
#  'DeleteDocumentConfigOrDict',
#  'DeleteFileConfig',
#  'DeleteFileConfigDict',
#  'DeleteFileConfigOrDict',
#  'DeleteFileResponse',
#  'DeleteFileResponseDict',
#  'DeleteFileResponseOrDict',
#  'DeleteFileSearchStoreConfig',
#  'DeleteFileSearchStoreConfigDict',
#  'DeleteFileSearchStoreConfigOrDict',
#  'DeleteModelConfig',
#  'DeleteModelConfigDict',
#  'DeleteModelConfigOrDict',
#  'DeleteModelResponse',
#  'DeleteModelResponseDict',
#  'DeleteModelResponseOrDict',
#  'DeleteResourceJob',
#  'DeleteResourceJobDict',
#  'DeleteResourceJobOrDict',
#  'Dict',
#  'DistillationDataStats',
#  'DistillationDataStatsDict',
#  'DistillationDataStatsOrDict',
#  'DistillationHyperParameters',
#  'DistillationHyperParametersDict',
#  'DistillationHyperParametersOrDict',
#  'DistillationSpec',
#  'DistillationSpecDict',
#  'DistillationSpecOrDict',
#  'Document',
#  'DocumentDict',
#  'DocumentOrDict',
#  'DocumentState',
#  'DownloadFileConfig',
#  'DownloadFileConfigDict',
#  'DownloadFileConfigOrDict',
#  'DynamicRetrievalConfig',
#  'DynamicRetrievalConfigDict',
#  'DynamicRetrievalConfigMode',
#  'DynamicRetrievalConfigOrDict',
#  'EditImageConfig',
#  'EditImageConfigDict',
#  'EditImageConfigOrDict',
#  'EditImageResponse',
#  'EditImageResponseDict',
#  'EditImageResponseOrDict',
#  'EditMode',
#  'EmbedContentBatch',
#  'EmbedContentBatchDict',
#  'EmbedContentBatchOrDict',
#  'EmbedContentConfig',
#  'EmbedContentConfigDict',
#  'EmbedContentConfigOrDict',
#  'EmbedContentMetadata',
#  'EmbedContentMetadataDict',
#  'EmbedContentMetadataOrDict',
#  'EmbedContentParameters',
#  'EmbedContentParametersDict',
#  'EmbedContentParametersOrDict',
#  'EmbedContentResponse',
#  'EmbedContentResponseDict',
#  'EmbedContentResponseOrDict',
#  'EmbeddingApiType',
#  'EmbeddingsBatchJobSource',
#  'EmbeddingsBatchJobSourceDict',
#  'EmbeddingsBatchJobSourceOrDict',
#  'EncryptionSpec',
#  'EncryptionSpecDict',
#  'EncryptionSpecOrDict',
#  'EndSensitivity',
#  'Endpoint',
#  'EndpointDict',
#  'EndpointOrDict',
#  'EnterpriseWebSearch',
#  'EnterpriseWebSearchDict',
#  'EnterpriseWebSearchOrDict',
#  'EntityLabel',
#  'EntityLabelDict',
#  'EntityLabelOrDict',
#  'Enum',
#  'EnumMeta',
#  'Environment',
#  'EvaluateDatasetResponse',
#  'EvaluateDatasetResponseDict',
#  'EvaluateDatasetResponseOrDict',
#  'EvaluateDatasetRun',
#  'EvaluateDatasetRunDict',
#  'EvaluateDatasetRunOrDict',
#  'EvaluationConfig',
#  'EvaluationConfigDict',
#  'EvaluationConfigOrDict',
#  'EvaluationDataset',
#  'EvaluationDatasetDict',
#  'EvaluationDatasetOrDict',
#  'ExactMatchMetricValue',
#  'ExactMatchMetricValueDict',
#  'ExactMatchMetricValueOrDict',
#  'ExecutableCode',
#  'ExecutableCodeDict',
#  'ExecutableCodeOrDict',
#  'ExternalApi',
#  'ExternalApiDict',
#  'ExternalApiElasticSearchParams',
#  'ExternalApiElasticSearchParamsDict',
#  'ExternalApiElasticSearchParamsOrDict',
#  'ExternalApiOrDict',
#  'ExternalApiSimpleSearchParams',
#  'ExternalApiSimpleSearchParamsDict',
#  'ExternalApiSimpleSearchParamsOrDict',
#  'FeatureSelectionPreference',
#  'FetchPredictOperationConfig',
#  'FetchPredictOperationConfigDict',
#  'FetchPredictOperationConfigOrDict',
#  'Field',
#  'File',
#  'FileData',
#  'FileDataDict',
#  'FileDataOrDict',
#  'FileDict',
#  'FileOrDict',
#  'FileSearch',
#  'FileSearchDict',
#  'FileSearchOrDict',
#  'FileSearchStore',
#  'FileSearchStoreDict',
#  'FileSearchStoreOrDict',
#  'FileSource',
#  'FileState',
#  'FileStatus',
#  'FileStatusDict',
#  'FileStatusOrDict',
#  'FinishReason',
#  'FullFineTuningSpec',
#  'FullFineTuningSpecDict',
#  'FullFineTuningSpecOrDict',
#  'FunctionCall',
#  'FunctionCallDict',
#  'FunctionCallOrDict',
#  'FunctionCallingConfig',
#  'FunctionCallingConfigDict',
#  'FunctionCallingConfigMode',
#  'FunctionCallingConfigOrDict',
#  'FunctionDeclaration',
#  'FunctionDeclarationDict',
#  'FunctionDeclarationOrDict',
#  'FunctionResponse',
#  'FunctionResponseBlob',
#  'FunctionResponseBlobDict',
#  'FunctionResponseBlobOrDict',
#  'FunctionResponseDict',
#  'FunctionResponseFileData',
#  'FunctionResponseFileDataDict',
#  'FunctionResponseFileDataOrDict',
#  'FunctionResponseOrDict',
#  'FunctionResponsePart',
#  'FunctionResponsePartDict',
#  'FunctionResponsePartOrDict',
#  'FunctionResponseScheduling',
#  'GcsDestination',
#  'GcsDestinationDict',
#  'GcsDestinationOrDict',
#  'GcsSource',
#  'GcsSourceDict',
#  'GcsSourceOrDict',
#  'GeminiPreferenceExample',
#  'GeminiPreferenceExampleCompletion',
#  'GeminiPreferenceExampleCompletionDict',
#  'GeminiPreferenceExampleCompletionOrDict',
#  'GeminiPreferenceExampleDict',
#  'GeminiPreferenceExampleOrDict',
#  'GenerateContentConfig',
#  'GenerateContentConfigDict',
#  'GenerateContentConfigOrDict',
#  'GenerateContentResponse',
#  'GenerateContentResponseDict',
#  'GenerateContentResponseOrDict',
#  'GenerateContentResponsePromptFeedback',
#  'GenerateContentResponsePromptFeedbackDict',
#  'GenerateContentResponsePromptFeedbackOrDict',
#  'GenerateContentResponseUsageMetadata',
#  'GenerateContentResponseUsageMetadataDict',
#  'GenerateContentResponseUsageMetadataOrDict',
#  'GenerateImagesConfig',
#  'GenerateImagesConfigDict',
#  'GenerateImagesConfigOrDict',
#  'GenerateImagesResponse',
#  'GenerateImagesResponseDict',
#  'GenerateImagesResponseOrDict',
#  'GenerateVideosConfig',
#  'GenerateVideosConfigDict',
#  'GenerateVideosConfigOrDict',
#  'GenerateVideosOperation',
#  'GenerateVideosResponse',
#  'GenerateVideosResponseDict',
#  'GenerateVideosResponseOrDict',
#  'GenerateVideosSource',
#  'GenerateVideosSourceDict',
#  'GenerateVideosSourceOrDict',
#  'GeneratedImage',
#  'GeneratedImageDict',
#  'GeneratedImageMask',
#  'GeneratedImageMaskDict',
#  'GeneratedImageMaskOrDict',
#  'GeneratedImageOrDict',
#  'GeneratedVideo',
#  'GeneratedVideoDict',
#  'GeneratedVideoOrDict',
#  'GenerationConfig',
#  'GenerationConfigDict',
#  'GenerationConfigOrDict',
#  'GenerationConfigRoutingConfig',
#  'GenerationConfigRoutingConfigAutoRoutingMode',
#  'GenerationConfigRoutingConfigAutoRoutingModeDict',
#  'GenerationConfigRoutingConfigAutoRoutingModeOrDict',
#  'GenerationConfigRoutingConfigDict',
#  'GenerationConfigRoutingConfigManualRoutingMode',
#  'GenerationConfigRoutingConfigManualRoutingModeDict',
#  'GenerationConfigRoutingConfigManualRoutingModeOrDict',
#  'GenerationConfigRoutingConfigOrDict',
#  'GenerationConfigThinkingConfig',
#  'GenerationConfigThinkingConfigDict',
#  'GenerationConfigThinkingConfigOrDict',
#  'GetBatchJobConfig',
#  'GetBatchJobConfigDict',
#  'GetBatchJobConfigOrDict',
#  'GetCachedContentConfig',
#  'GetCachedContentConfigDict',
#  'GetCachedContentConfigOrDict',
#  'GetDocumentConfig',
#  'GetDocumentConfigDict',
#  'GetDocumentConfigOrDict',
#  'GetFileConfig',
#  'GetFileConfigDict',
#  'GetFileConfigOrDict',
#  'GetFileSearchStoreConfig',
#  'GetFileSearchStoreConfigDict',
#  'GetFileSearchStoreConfigOrDict',
#  'GetModelConfig',
#  'GetModelConfigDict',
#  'GetModelConfigOrDict',
#  'GetOperationConfig',
#  'GetOperationConfigDict',
#  'GetOperationConfigOrDict',
#  'GetTuningJobConfig',
#  'GetTuningJobConfigDict',
#  'GetTuningJobConfigOrDict',
#  'GoogleMaps',
#  'GoogleMapsDict',
#  'GoogleMapsOrDict',
#  'GoogleRpcStatus',
#  'GoogleRpcStatusDict',
#  'GoogleRpcStatusOrDict',
#  'GoogleSearch',
#  'GoogleSearchDict',
#  'GoogleSearchOrDict',
#  'GoogleSearchRetrieval',
#  'GoogleSearchRetrievalDict',
#  'GoogleSearchRetrievalOrDict',
#  'GoogleTypeDate',
#  'GoogleTypeDateDict',
#  'GoogleTypeDateOrDict',
#  'GroundingChunk',
#  'GroundingChunkDict',
#  'GroundingChunkImage',
#  'GroundingChunkImageDict',
#  'GroundingChunkImageOrDict',
#  'GroundingChunkMaps',
#  'GroundingChunkMapsDict',
#  'GroundingChunkMapsOrDict',
#  'GroundingChunkMapsPlaceAnswerSources',
#  'GroundingChunkMapsPlaceAnswerSourcesAuthorAttribution',
#  'GroundingChunkMapsPlaceAnswerSourcesAuthorAttributionDict',
#  'GroundingChunkMapsPlaceAnswerSourcesAuthorAttributionOrDict',
#  'GroundingChunkMapsPlaceAnswerSourcesDict',
#  'GroundingChunkMapsPlaceAnswerSourcesOrDict',
#  'GroundingChunkMapsPlaceAnswerSourcesReviewSnippet',
#  'GroundingChunkMapsPlaceAnswerSourcesReviewSnippetDict',
#  'GroundingChunkMapsPlaceAnswerSourcesReviewSnippetOrDict',
#  'GroundingChunkOrDict',
#  'GroundingChunkRetrievedContext',
#  'GroundingChunkRetrievedContextDict',
#  'GroundingChunkRetrievedContextOrDict',
#  'GroundingChunkWeb',
#  'GroundingChunkWebDict',
#  'GroundingChunkWebOrDict',
#  'GroundingMetadata',
#  'GroundingMetadataDict',
#  'GroundingMetadataOrDict',
#  'GroundingMetadataSourceFlaggingUri',
#  'GroundingMetadataSourceFlaggingUriDict',
#  'GroundingMetadataSourceFlaggingUriOrDict',
#  'GroundingSupport',
#  'GroundingSupportDict',
#  'GroundingSupportOrDict',
#  'HarmBlockMethod',
#  'HarmBlockThreshold',
#  'HarmCategory',
#  'HarmProbability',
#  'HarmSeverity',
#  'HistoryConfig',
#  'HistoryConfigDict',
#  'HistoryConfigOrDict',
#  'HttpElementLocation',
#  'HttpOptions',
#  'HttpOptionsDict',
#  'HttpOptionsOrDict',
#  'HttpResponse',
#  'HttpResponseDict',
#  'HttpResponseOrDict',
#  'HttpRetryOptions',
#  'HttpRetryOptionsDict',
#  'HttpRetryOptionsOrDict',
#  'HttpxAsyncClient',
#  'HttpxClient',
#  'Image',
#  'ImageConfig',
#  'ImageConfigDict',
#  'ImageConfigImageOutputOptions',
#  'ImageConfigImageOutputOptionsDict',
#  'ImageConfigImageOutputOptionsOrDict',
#  'ImageConfigOrDict',
#  'ImageDict',
#  'ImageOrDict',
#  'ImagePromptLanguage',
#  'ImageSearch',
#  'ImageSearchDict',
#  'ImageSearchOrDict',
#  'ImportFileConfig',
#  'ImportFileConfigDict',
#  'ImportFileConfigOrDict',
#  'ImportFileOperation',
#  'ImportFileResponse',
#  'ImportFileResponseDict',
#  'ImportFileResponseOrDict',
#  'InlinedEmbedContentResponse',
#  'InlinedEmbedContentResponseDict',
#  'InlinedEmbedContentResponseOrDict',
#  'InlinedRequest',
#  'InlinedRequestDict',
#  'InlinedRequestOrDict',
#  'InlinedResponse',
#  'InlinedResponseDict',
#  'InlinedResponseOrDict',
#  'Interval',
#  'IntervalDict',
#  'IntervalOrDict',
#  'JOB_STATES_ENDED',
#  'JOB_STATES_ENDED_MLDEV',
#  'JOB_STATES_ENDED_VERTEX',
#  'JOB_STATES_SUCCEEDED',
#  'JOB_STATES_SUCCEEDED_MLDEV',
#  'JOB_STATES_SUCCEEDED_VERTEX',
#  'JSONSchema',
#  'JSONSchemaType',
#  'JobError',
#  'JobErrorDict',
#  'JobErrorOrDict',
#  'JobState',
#  'LLMBasedMetricSpec',
#  'LLMBasedMetricSpecDict',
#  'LLMBasedMetricSpecOrDict',
#  'Language',
#  'LatLng',
#  'LatLngDict',
#  'LatLngOrDict',
#  'List',
#  'ListBatchJobsConfig',
#  'ListBatchJobsConfigDict',
#  'ListBatchJobsConfigOrDict',
#  'ListBatchJobsResponse',
#  'ListBatchJobsResponseDict',
#  'ListBatchJobsResponseOrDict',
#  'ListCachedContentsConfig',
#  'ListCachedContentsConfigDict',
#  'ListCachedContentsConfigOrDict',
#  'ListCachedContentsResponse',
#  'ListCachedContentsResponseDict',
#  'ListCachedContentsResponseOrDict',
#  'ListDocumentsConfig',
#  'ListDocumentsConfigDict',
#  'ListDocumentsConfigOrDict',
#  'ListDocumentsResponse',
#  'ListDocumentsResponseDict',
#  'ListDocumentsResponseOrDict',
#  'ListFileSearchStoresConfig',
#  'ListFileSearchStoresConfigDict',
#  'ListFileSearchStoresConfigOrDict',
#  'ListFileSearchStoresResponse',
#  'ListFileSearchStoresResponseDict',
#  'ListFileSearchStoresResponseOrDict',
#  'ListFilesConfig',
#  'ListFilesConfigDict',
#  'ListFilesConfigOrDict',
#  'ListFilesResponse',
#  'ListFilesResponseDict',
#  'ListFilesResponseOrDict',
#  'ListModelsConfig',
#  'ListModelsConfigDict',
#  'ListModelsConfigOrDict',
#  'ListModelsResponse',
#  'ListModelsResponseDict',
#  'ListModelsResponseOrDict',
#  'ListTuningJobsConfig',
#  'ListTuningJobsConfigDict',
#  'ListTuningJobsConfigOrDict',
#  'ListTuningJobsResponse',
#  'ListTuningJobsResponseDict',
#  'ListTuningJobsResponseOrDict',
#  'Literal',
#  'LiveClientContent',
#  'LiveClientContentDict',
#  'LiveClientContentOrDict',
#  'LiveClientMessage',
#  'LiveClientMessageDict',
#  'LiveClientMessageOrDict',
#  'LiveClientRealtimeInput',
#  'LiveClientRealtimeInputDict',
#  'LiveClientRealtimeInputOrDict',
#  'LiveClientSetup',
#  'LiveClientSetupDict',
#  'LiveClientSetupOrDict',
#  'LiveClientToolResponse',
#  'LiveClientToolResponseDict',
#  'LiveClientToolResponseOrDict',
#  'LiveConnectConfig',
#  'LiveConnectConfigDict',
#  'LiveConnectConfigOrDict',
#  'LiveConnectConstraints',
#  'LiveConnectConstraintsDict',
#  'LiveConnectConstraintsOrDict',
#  'LiveConnectParameters',
#  'LiveConnectParametersDict',
#  'LiveConnectParametersOrDict',
#  'LiveMusicClientContent',
#  'LiveMusicClientContentDict',
#  'LiveMusicClientContentOrDict',
#  'LiveMusicClientMessage',
#  'LiveMusicClientMessageDict',
#  'LiveMusicClientMessageOrDict',
#  'LiveMusicClientSetup',
#  'LiveMusicClientSetupDict',
#  'LiveMusicClientSetupOrDict',
#  'LiveMusicConnectParameters',
#  'LiveMusicConnectParametersDict',
#  'LiveMusicConnectParametersOrDict',
#  'LiveMusicFilteredPrompt',
#  'LiveMusicFilteredPromptDict',
#  'LiveMusicFilteredPromptOrDict',
#  'LiveMusicGenerationConfig',
#  'LiveMusicGenerationConfigDict',
#  'LiveMusicGenerationConfigOrDict',
#  'LiveMusicPlaybackControl',
#  'LiveMusicServerContent',
#  'LiveMusicServerContentDict',
#  'LiveMusicServerContentOrDict',
#  'LiveMusicServerMessage',
#  'LiveMusicServerMessageDict',
#  'LiveMusicServerMessageOrDict',
#  'LiveMusicServerSetupComplete',
#  'LiveMusicServerSetupCompleteDict',
#  'LiveMusicServerSetupCompleteOrDict',
#  'LiveMusicSetConfigParameters',
#  'LiveMusicSetConfigParametersDict',
#  'LiveMusicSetConfigParametersOrDict',
#  'LiveMusicSetWeightedPromptsParameters',
#  'LiveMusicSetWeightedPromptsParametersDict',
#  'LiveMusicSetWeightedPromptsParametersOrDict',
#  'LiveMusicSourceMetadata',
#  'LiveMusicSourceMetadataDict',
#  'LiveMusicSourceMetadataOrDict',
#  'LiveSendRealtimeInputParameters',
#  'LiveSendRealtimeInputParametersDict',
#  'LiveSendRealtimeInputParametersOrDict',
#  'LiveServerContent',
#  'LiveServerContentDict',
#  'LiveServerContentOrDict',
#  'LiveServerGoAway',
#  'LiveServerGoAwayDict',
#  'LiveServerGoAwayOrDict',
#  'LiveServerMessage',
#  'LiveServerMessageDict',
#  'LiveServerMessageOrDict',
#  'LiveServerSessionResumptionUpdate',
#  'LiveServerSessionResumptionUpdateDict',
#  'LiveServerSessionResumptionUpdateOrDict',
#  'LiveServerSetupComplete',
#  'LiveServerSetupCompleteDict',
#  'LiveServerSetupCompleteOrDict',
#  'LiveServerToolCall',
#  'LiveServerToolCallCancellation',
#  'LiveServerToolCallCancellationDict',
#  'LiveServerToolCallCancellationOrDict',
#  'LiveServerToolCallDict',
#  'LiveServerToolCallOrDict',
#  'LogprobsResult',
#  'LogprobsResultCandidate',
#  'LogprobsResultCandidateDict',
#  'LogprobsResultCandidateOrDict',
#  'LogprobsResultDict',
#  'LogprobsResultOrDict',
#  'LogprobsResultTopCandidates',
#  'LogprobsResultTopCandidatesDict',
#  'LogprobsResultTopCandidatesOrDict',
#  'MaskReferenceConfig',
#  'MaskReferenceConfigDict',
#  'MaskReferenceConfigOrDict',
#  'MaskReferenceImage',
#  'MaskReferenceImageDict',
#  'MaskReferenceImageOrDict',
#  'MaskReferenceMode',
#  'McpCallToolResult',
#  'McpClientSession',
#  'McpServer',
#  'McpServerDict',
#  'McpServerOrDict',
#  'MediaModality',
#  'MediaResolution',
#  'Metric',
#  'MetricDict',
#  'MetricOrDict',
#  'MetricSubclass',
#  'MetricUnion',
#  'MetricUnionDict',
#  'Modality',
#  'ModalityTokenCount',
#  'ModalityTokenCountDict',
#  'ModalityTokenCountOrDict',
#  'Model',
#  'ModelArmorConfig',
#  'ModelArmorConfigDict',
#  'ModelArmorConfigOrDict',
#  'ModelContent',
#  'ModelDict',
#  'ModelOrDict',
#  'ModelSelectionConfig',
#  'ModelSelectionConfigDict',
#  'ModelSelectionConfigOrDict',
#  'MultiSpeakerVoiceConfig',
#  'MultiSpeakerVoiceConfigDict',
#  'MultiSpeakerVoiceConfigOrDict',
#  'MusicGenerationMode',
#  'Operation',
#  'Optional',
#  'Outcome',
#  'OutputConfig',
#  'OutputConfigDict',
#  'OutputConfigOrDict',
#  'OutputInfo',
#  'OutputInfoDict',
#  'OutputInfoOrDict',
#  'PIL',
#  'PIL_Image',
#  'PairwiseChoice',
#  'PairwiseMetricResult',
#  'PairwiseMetricResultDict',
#  'PairwiseMetricResultOrDict',
#  'PairwiseMetricSpec',
#  'PairwiseMetricSpecDict',
#  'PairwiseMetricSpecOrDict',
#  'Part',
#  'PartDict',
#  'PartMediaResolution',
#  'PartMediaResolutionDict',
#  'PartMediaResolutionLevel',
#  'PartMediaResolutionOrDict',
#  'PartOrDict',
#  'PartUnion',
#  'PartUnionDict',
#  'PartialArg',
#  'PartialArgDict',
#  'PartialArgOrDict',
#  'PartnerModelTuningSpec',
#  'PartnerModelTuningSpecDict',
#  'PartnerModelTuningSpecOrDict',
#  'PersonGeneration',
#  'PhishBlockThreshold',
#  'PointwiseMetricResult',
#  'PointwiseMetricResultDict',
#  'PointwiseMetricResultOrDict',
#  'PointwiseMetricSpec',
#  'PointwiseMetricSpecDict',
#  'PointwiseMetricSpecOrDict',
#  'PreTunedModel',
#  'PreTunedModelDict',
#  'PreTunedModelOrDict',
#  'PrebuiltVoiceConfig',
#  'PrebuiltVoiceConfigDict',
#  'PrebuiltVoiceConfigOrDict',
#  'PredefinedMetricSpec',
#  'PredefinedMetricSpecDict',
#  'PredefinedMetricSpecOrDict',
#  'PreferenceOptimizationDataStats',
#  'PreferenceOptimizationDataStatsDict',
#  'PreferenceOptimizationDataStatsOrDict',
#  'PreferenceOptimizationHyperParameters',
#  'PreferenceOptimizationHyperParametersDict',
#  'PreferenceOptimizationHyperParametersOrDict',
#  'PreferenceOptimizationSpec',
#  'PreferenceOptimizationSpecDict',
#  'PreferenceOptimizationSpecOrDict',
#  'PrivateAttr',
#  'ProactivityConfig',
#  'ProactivityConfigDict',
#  'ProactivityConfigOrDict',
#  'ProductImage',
#  'ProductImageDict',
#  'ProductImageOrDict',
#  'ProjectOperation',
#  'ProjectOperationDict',
#  'ProjectOperationOrDict',
#  'ProminentPeople',
#  'RagChunk',
#  'RagChunkDict',
#  'RagChunkOrDict',
#  'RagChunkPageSpan',
#  'RagChunkPageSpanDict',
#  'RagChunkPageSpanOrDict',
#  'RagRetrievalConfig',
#  'RagRetrievalConfigDict',
#  'RagRetrievalConfigFilter',
#  'RagRetrievalConfigFilterDict',
#  'RagRetrievalConfigFilterOrDict',
#  'RagRetrievalConfigHybridSearch',
#  'RagRetrievalConfigHybridSearchDict',
#  'RagRetrievalConfigHybridSearchOrDict',
#  'RagRetrievalConfigOrDict',
#  'RagRetrievalConfigRanking',
#  'RagRetrievalConfigRankingDict',
#  'RagRetrievalConfigRankingLlmRanker',
#  'RagRetrievalConfigRankingLlmRankerDict',
#  'RagRetrievalConfigRankingLlmRankerOrDict',
#  'RagRetrievalConfigRankingOrDict',
#  'RagRetrievalConfigRankingRankService',
#  'RagRetrievalConfigRankingRankServiceDict',
#  'RagRetrievalConfigRankingRankServiceOrDict',
#  'RawOutput',
#  'RawOutputDict',
#  'RawOutputOrDict',
#  'RawReferenceImage',
#  'RawReferenceImageDict',
#  'RawReferenceImageOrDict',
#  'RealtimeInputConfig',
#  'RealtimeInputConfigDict',
#  'RealtimeInputConfigOrDict',
#  'RecontextImageConfig',
#  'RecontextImageConfigDict',
#  'RecontextImageConfigOrDict',
#  'RecontextImageResponse',
#  'RecontextImageResponseDict',
#  'RecontextImageResponseOrDict',
#  'RecontextImageSource',
#  'RecontextImageSourceDict',
#  'RecontextImageSourceOrDict',
#  'RegisterFilesConfig',
#  'RegisterFilesConfigDict',
#  'RegisterFilesConfigOrDict',
#  'RegisterFilesResponse',
#  'RegisterFilesResponseDict',
#  'RegisterFilesResponseOrDict',
#  'ReplayFile',
#  'ReplayFileDict',
#  'ReplayFileOrDict',
#  'ReplayInteraction',
#  'ReplayInteractionDict',
#  'ReplayInteractionOrDict',
#  'ReplayRequest',
#  'ReplayRequestDict',
#  'ReplayRequestOrDict',
#  'ReplayResponse',
#  'ReplayResponseDict',
#  'ReplayResponseOrDict',
#  'ReplicatedVoiceConfig',
#  'ReplicatedVoiceConfigDict',
#  'ReplicatedVoiceConfigOrDict',
#  'ResourceScope',
#  'Retrieval',
#  'RetrievalConfig',
#  'RetrievalConfigDict',
#  'RetrievalConfigOrDict',
#  'RetrievalDict',
#  'RetrievalMetadata',
#  'RetrievalMetadataDict',
#  'RetrievalMetadataOrDict',
#  'RetrievalOrDict',
#  'RougeMetricValue',
#  'RougeMetricValueDict',
#  'RougeMetricValueOrDict',
#  'RougeSpec',
#  'RougeSpecDict',
#  'RougeSpecOrDict',
#  'RubricContentType',
#  'RubricGenerationSpec',
#  'RubricGenerationSpecDict',
#  'RubricGenerationSpecOrDict',
#  'SafetyAttributes',
#  'SafetyAttributesDict',
#  'SafetyAttributesOrDict',
#  'SafetyFilterLevel',
#  'SafetyRating',
#  'SafetyRatingDict',
#  'SafetyRatingOrDict',
#  'SafetySetting',
#  'SafetySettingDict',
#  'SafetySettingOrDict',
#  'Scale',
#  'Schema',
#  'SchemaDict',
#  'SchemaOrDict',
#  'SchemaUnion',
#  'SchemaUnionDict',
#  'ScribbleImage',
#  'ScribbleImageDict',
#  'ScribbleImageOrDict',
#  'SearchEntryPoint',
#  'SearchEntryPointDict',
#  'SearchEntryPointOrDict',
#  'SearchTypes',
#  'SearchTypesDict',
#  'SearchTypesOrDict',
#  'Segment',
#  'SegmentDict',
#  'SegmentImageConfig',
#  'SegmentImageConfigDict',
#  'SegmentImageConfigOrDict',
#  'SegmentImageResponse',
#  'SegmentImageResponseDict',
#  'SegmentImageResponseOrDict',
#  'SegmentImageSource',
#  'SegmentImageSourceDict',
#  'SegmentImageSourceOrDict',
#  'SegmentMode',
#  'SegmentOrDict',
#  'Self',
#  'Sequence',
#  'SessionResumptionConfig',
#  'SessionResumptionConfigDict',
#  'SessionResumptionConfigOrDict',
#  'SingleEmbedContentResponse',
#  'SingleEmbedContentResponseDict',
#  'SingleEmbedContentResponseOrDict',
#  'SlidingWindow',
#  'SlidingWindowDict',
#  'SlidingWindowOrDict',
#  'SpeakerVoiceConfig',
#  'SpeakerVoiceConfigDict',
#  'SpeakerVoiceConfigOrDict',
#  'SpeechConfig',
#  'SpeechConfigDict',
#  'SpeechConfigOrDict',
#  'SpeechConfigUnion',
#  'SpeechConfigUnionDict',
#  'StartSensitivity',
#  'StreamableHttpTransport',
#  'StreamableHttpTransportDict',
#  'StreamableHttpTransportOrDict',
#  ...]

# %%
print(dir(types))
